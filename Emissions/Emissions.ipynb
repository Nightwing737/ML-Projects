# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Data = pd.read_csv("Methane_final.csv")
Val = Data[Data["region"] != "World"]
Val
# Out:
#       Unnamed: 0            region     country   emissions         type  \
# 0              0            Africa     Algeria  257.611206  Agriculture
# 1              1            Africa     Algeria    0.052000       Energy
# 2              2            Africa     Algeria  130.798996       Energy
# 3              3            Africa     Algeria   69.741898       Energy
# 4              4            Africa     Algeria  213.987000       Energy
# ...          ...               ...         ...         ...          ...
# 1521        1521  Russia & Caspian  Uzbekistan   16.973917       Energy
# 1522        1522  Russia & Caspian  Uzbekistan   18.299999       Energy
# 1523        1523  Russia & Caspian  Uzbekistan  780.916138       Energy
# 1524        1524  Russia & Caspian  Uzbekistan    3.845616        Other
# 1525        1525  Russia & Caspian  Uzbekistan  280.418243        Waste
#
#                                              segment    reason   baseYear  \
# ...

# %%
All = pd.unique(Val["region"])
print(All)
# Out:
# ['Africa' 'Asia Pacific' 'Central and South America' 'Europe'
#  'Middle East' 'North America' 'Other' 'Russia & Caspian']

# %%
for i in range(0,All.size):
    region = All[i]
    print(region)
    Val = Data[Data["region"].isin([region])]
    Total = Val["emissions"].sum()
    print(Total)
# Out:
# Africa
# 54197.15261313948
# Asia Pacific
# 177699.61146502104
# Central and South America
# 45639.98979930533
# Europe
# 49208.99681790243
# Middle East
# 38095.79876317829
# North America
# 63347.40917745978
# Other
# 15997.35717530927
# Russia & Caspian
# 62421.61236039363
