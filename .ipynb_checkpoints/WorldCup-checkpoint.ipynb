# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Data = pd.read_csv("WorldCupMatches.csv")
Data.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
keep_columns = ["Year","Stage","Home Team Name","Home Team Goals", "Away Team Goals", "Away Team Goals","Attendance"]
Val = Data[Data.columns.intersection(keep_columns)].dropna()
Val
# Out:
#        Year                     Stage Home Team Name  Home Team Goals  \
# 0    1930.0                   Group 1         France              4.0
# 1    1930.0                   Group 4            USA              3.0
# 2    1930.0                   Group 2     Yugoslavia              2.0
# 3    1930.0                   Group 3        Romania              3.0
# 4    1930.0                   Group 1      Argentina              1.0
# ..      ...                       ...            ...              ...
# 847  2014.0            Quarter-finals    Netherlands              0.0
# 848  2014.0               Semi-finals         Brazil              1.0
# 849  2014.0               Semi-finals    Netherlands              0.0
# 850  2014.0  Play-off for third place         Brazil              0.0
# 851  2014.0                     Final        Germany              1.0
#
#      Away Team Goals  Attendance
# 0                1.0      4444.0
# 1                0.0     18346.0
# ...

# %%
print(pd.unique(Val["Home Team Name"]))
print(pd.unique(Val["Stage"]))
# Out:
# ['France' 'USA' 'Yugoslavia' 'Romania' 'Argentina' 'Chile' 'Uruguay'
#  'Brazil' 'Paraguay' 'Austria' 'Hungary' 'Switzerland' 'Sweden' 'Germany'
#  'Spain' 'Italy' 'Czechoslovakia' 'Cuba' 'England' 'Germany FR' 'Turkey'
#  'Soviet Union' 'Northern Ireland' 'Mexico' 'Wales' 'Portugal' 'Korea DPR'
#  'Peru' 'Belgium' 'Bulgaria' 'German DR' 'Zaire' 'Poland' 'Australia'
#  'Scotland' 'Netherlands' 'Haiti' 'Tunisia' 'Algeria' 'Honduras' 'Canada'
#  'Morocco' 'Korea Republic' 'Iraq' 'Denmark' 'rn">United Arab Emirates'
#  'Costa Rica' 'Cameroon' 'rn">Republic of Ireland' 'Colombia' 'Norway'
#  'Nigeria' 'Saudi Arabia' 'Bolivia' 'Russia' 'Greece' 'Jamaica'
#  'South Africa' 'Japan' 'Croatia' 'China PR' 'Senegal' 'Slovenia'
#  'Ecuador' 'rn">Trinidad and Tobago' 'rn">Serbia and Montenegro' 'Angola'
#  'Czech Republic' 'Togo' 'Iran' "C�te d'Ivoire" 'Ghana' 'Ukraine' 'Serbia'
#  'New Zealand' 'Slovakia' 'IR Iran' 'rn">Bosnia and Herzegovina']
# ...

# %%
Val["Count"] = 0
One = ["Group 1","Group 2","Group 3","Group 4","Group 5","Group 6","Group A","Group B","Group C","Group D","Group E","Group F","Group G","Group H"]
Val.loc[Val["Stage"].isin(One),"Count"]=1
#TODO: Factor in both Home and Away Team
# Out:
#        Year                     Stage Home Team Name  Home Team Goals  \
# 0    1930.0                   Group 1         France              4.0
# 1    1930.0                   Group 4            USA              3.0
# 2    1930.0                   Group 2     Yugoslavia              2.0
# 3    1930.0                   Group 3        Romania              3.0
# 4    1930.0                   Group 1      Argentina              1.0
# ..      ...                       ...            ...              ...
# 847  2014.0            Quarter-finals    Netherlands              0.0
# 848  2014.0               Semi-finals         Brazil              1.0
# 849  2014.0               Semi-finals    Netherlands              0.0
# 850  2014.0  Play-off for third place         Brazil              0.0
# 851  2014.0                     Final        Germany              1.0
#
#      Away Team Goals  Attendance  Count
# 0                1.0      4444.0      1
# 1                0.0     18346.0      1
# ...
