# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('datatraining.csv')
to_drop = ['date']
data.drop(to_drop, inplace = True, axis = 1)
data.rename(columns = {'S.no.':'Number'}, inplace = True)
data
# Out:
#       Number  Temperature  Humidity  Light         CO2  HumidityRatio  \
# 0          1        23.18   27.2720  426.0  721.250000       0.004793
# 1          2        23.15   27.2675  429.5  714.000000       0.004783
# 2          3        23.15   27.2450  426.0  713.500000       0.004779
# 3          4        23.15   27.2000  426.0  708.250000       0.004772
# 4          5        23.10   27.2000  426.0  704.500000       0.004757
# ...      ...          ...       ...    ...         ...            ...
# 8138    8139        21.05   36.0975  433.0  787.250000       0.005579
# 8139    8140        21.05   35.9950  433.0  789.500000       0.005563
# 8140    8141        21.10   36.0950  433.0  798.500000       0.005596
# 8141    8142        21.10   36.2600  433.0  820.333333       0.005621
# 8142    8143        21.10   36.2000  447.0  821.000000       0.005612
#
#       Occupancy
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# ...

# %%
Number = data['Number']
Temperature = data['Temperature']
Humidity = data['Humidity']
Light = data['Light']
CO2 = data['CO2']
HumidityRatio = data['HumidityRatio']
Occupancy = data['Occupancy']

# %%
fig = plt.figure()
myaxes = fig.add_axes([1, 1, 1, 1])
myaxes.plot(Number,Temperature,'r',label = 'Temperature')
myaxes.legend()

fig = plt.figure()
myaxes2 = fig.add_axes([1, 1, 1, 1])
myaxes2.plot(Number,Humidity,'b',label = 'Humidity')
myaxes2.legend()

fig = plt.figure()
myaxes3 = fig.add_axes([1, 1, 1, 1])
myaxes3.plot(Number,Light,'y',label = 'Light')
myaxes3.legend()

fig = plt.figure()
myaxes4 = fig.add_axes([1, 1, 1, 1])
myaxes4.plot(Number,Temperature,'purple',label = 'CO2')
myaxes4.legend()

fig = plt.figure()
myaxes5 = fig.add_axes([1, 1, 1, 1])
myaxes5.plot(Number,HumidityRatio,'g',label = 'HumidityRatio')
myaxes5.legend()

fig = plt.figure()
myaxes6 = fig.add_axes([1,1,1,1])
myaxes6.scatter(Number,Occupancy,s=10, color=(0,0,0),alpha=0.5)
