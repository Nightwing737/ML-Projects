# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Data = pd.read_csv(r"C:\Users\aryan\Downloads\ML Projects\dataset.csv")

drops = ["SNo","timestamp","volume","open","close"]
Data.drop(drops, inplace=True, axis=1)

Year = int(2013)
Month = 5
Currency = "Bitcoin"

TVal = Data[Data["Year"].isin([Year])] 
LVal = TVal[TVal["Month"].isin([Month])]
CVal = LVal[LVal["crypto_name"].isin([Currency])]

Val = CVal.round(decimals = 2)
Val
# Out:
#       high     low     marketCap crypto_name       date  Day  Month  Year
# 0   118.80  107.14  1.288693e+09     Bitcoin   5/5/2013    5      5  2013
# 2   124.66  106.64  1.249023e+09     Bitcoin   5/6/2013    6      5  2013
# 4   113.44   97.70  1.240594e+09     Bitcoin   5/7/2013    7      5  2013
# 7   115.78  109.60  1.264049e+09     Bitcoin   5/8/2013    8      5  2013
# 9   113.46  109.26  1.254535e+09     Bitcoin   5/9/2013    9      5  2013
# 10  122.00  111.55  1.305479e+09     Bitcoin  5/10/2013   10      5  2013
# 12  118.68  113.01  1.284207e+09     Bitcoin  5/11/2013   11      5  2013
# 15  117.45  113.43  1.281983e+09     Bitcoin  5/12/2013   12      5  2013
# 17  118.70  114.50  1.315710e+09     Bitcoin  5/13/2013   13      5  2013
# 18  119.80  110.25  1.243874e+09     Bitcoin  5/14/2013   14      5  2013
# 20  115.81  103.50  1.274624e+09     Bitcoin  5/15/2013   15      5  2013
# 22  118.76  112.20  1.325727e+09     Bitcoin  5/16/2013   16      5  2013
# 24  125.30  116.57  1.373724e+09     Bitcoin  5/17/2013   17      5  2013
# 27  125.25  122.30  1.379575e+09     Bitcoin  5/18/2013   18      5  2013
# 29  124.50  119.57  1.363205e+09     Bitcoin  5/19/2013   19      5  2013
# 30  123.62  120.12  1.363710e+09     Bitcoin  5/20/2013   20      5  2013
# 33  123.00  121.21  1.374013e+09     Bitcoin  5/21/2013   21      5  2013
# 35  124.00  122.00  1.385779e+09     Bitcoin  5/22/2013   22      5  2013
# 36  126.93  123.10  1.417770e+09     Bitcoin  5/23/2013   23      5  2013
# 39  133.85  125.72  1.491071e+09     Bitcoin  5/24/2013   24      5  2013
# 41  133.22  128.90  1.477958e+09     Bitcoin  5/25/2013   25      5  2013
# 42  136.00  130.62  1.495293e+09     Bitcoin  5/26/2013   26      5  2013
# 44  135.46  124.70  1.454030e+09     Bitcoin  5/27/2013   27      5  2013
# 46  130.58  125.60  1.446190e+09     Bitcoin  5/28/2013   28      5  2013
# 48  132.59  127.66  1.483735e+09     Bitcoin  5/29/2013   29      5  2013
# 51  132.25  127.00  1.445054e+09     Bitcoin  5/30/2013   30      5  2013
# 52  129.90  126.40  1.447870e+09     Bitcoin  5/31/2013   31      5  2013

# %%
X = Val["Day"]

Y = Val["high"]
W = Val["low"]

# %%
fig, ax = plt.subplots()
m, b = np.polyfit(X,Y,1)
n, c = np.polyfit(X,W,1)
ax.plot(X,Y, label = "Highest")
ax.plot(X,W, label = "Lowest")

ax.plot(X,((m*X+b)+(n*X+c))/2)

ax.set_title(f"{Currency} prices in {Year}")
LabelX = ax.set_xlabel("Day")
LabelY = ax.set_ylabel("Stock Prices")

plt.legend()
plt.show()
